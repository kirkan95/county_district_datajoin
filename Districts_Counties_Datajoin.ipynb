# %% [markdown]
# For the Unfair Burden tax story, we're creating a news game intended to demonstrate how easy it is to get a multi-million dollar tax break in Texas. As a part of the game, we want a map displaying each school district and the artificial cap on a tax break, and want to display which county the school district is in. In order to create that map, we need to first join two datasets together: One dataset with the school district name and artificial cap, and one dataset with the school district name and the county/counties that the district lies within.

# %%
import pandas as pd
df1=pd.read_csv("districts.csv")
df2=pd.read_csv('DistCounty.csv', sep='delimiter')
print(df1.head(2))
# Out:
#   Independent School District Name    ISD # Subject to Subchapter C  \
# 0                           Abbott  109-901                     YES
# 1                        Abernathy  095-901                     YES
#
#   Category #  \
# 0        III
# 1          I
#
#   Subject to Subchapter C Because of Demographics Characteristics [Sec.313.051(a-1)(2)]  \
# 0                                                YES
# 1                                                YES
#
#   Minimum Limitation Amount [Sec.313.053]  \
# 0                             $20 Million
# 1                             $30 Million
#
#   Minimum Qualified Investment Amount [Sec.313.054]
# 0                                       $10 Million
# 1                                       $30 Million
# ...

# %%
print(df1)
# Out:
#      Independent School District Name    ISD # Subject to Subchapter C  \
# 0                              Abbott  109-901                     YES
# 1                           Abernathy  095-901                     YES
# 2                             Abilene  221-901                     YES
# 3                             Academy  014-901                     YES
# 4                              Adrian  180-903                     YES
# ...                               ...      ...                     ...
# 1011                         Yorktown  062-904                     YES
# 1012                           Ysleta  071-905                     YES
# 1013                           Zapata  253-901                     YES
# 1014                          Zavalla  003-906                     YES
# 1015                           Zephyr  025-906                     YES
#
#      Category #  \
# 0           III
# 1             I
# 2             I
# 3           III
# 4             I
# ...

# %%
print(df2.head(2))
# Out:
#   "District Number","District Name","All Intersecting Counties ->"
# 0     001902,Cayuga ISD,ANDERSON,FREESTONE,HENDERSON
# 1           001903,Elkhart ISD,ANDERSON,HOUSTON,LEON

# %%
df2 = df2.drop(columns=["\"District Number\""])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-aa741d9059f2> in <module>
# ----> 1 df2 = df2.drop(columns=["\"District Number\""])
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...
